# %% [markdown]
# # Using `pandas` to investigate pay gap data

# %%
import pandas

# %% [markdown]
# ## Read the data from the `csv` file
#
# This data was taken directly from the ONS at https://gender-pay-gap.service.gov.uk/viewing/download
#
# > What does `csv` stand for?

# %%
data = pandas.read_csv("PayGapData1819.csv")

# %% [markdown]
# ## Look at the first few rows

# %%
data.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                            1509 GROUP
#
#                                              Address CompanyNumber  \
# 0  Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...      00226143
# 1  19 Smith's Place,\r\nLeith Walk,\r\nEdinburgh,...      SC016876
# 2  Fusion Point,\r\nDumballs Road,\r\nCardiff,\r\...      03951948
# 3  34 Roundhay Road,\r\nLeeds,\r\nEngland,\r\nLS7...      10530651
# 4  Royal Grammar School, High Street,\r\nGuildfor...      04104101
#
#           SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 0            85310                   19.6                     32.5
# 1            47730                    7.7                     -4.2
# 2            61900                    7.7                     12.7
# 3            78300                   30.0                     29.0
# 4  85200,\r\n85310                   13.4                     12.7
#
#    DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 0                   NaN                     NaN               0.0
# 1                  23.7                   -75.2              22.2
# 2                  11.3                    10.9              67.0
# 3                 -10.0                    69.0              46.0
# 4                   0.0                     0.0               0.0
#
#    FemaleBonusPercent  ...  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0                 0.0  ...                       55.1             53.3
# 1                82.0  ...                       88.4             20.3
# 2                52.0  ...                       50.0             56.0
# 3                74.0  ...                       83.0             25.0
# 4                 0.0  ...                       51.6             61.3
#
#    FemaleTopQuartile                    CompanyLinkToGPGInfo  \
# 0               46.7  https://www.bryanston.co.uk/employment
# 1               79.7                                     NaN
# 2               44.0                                     NaN
# 3               75.0                                     NaN
# 4               38.7         https://www.rgs-guildford.co.uk
#
#                             ResponsiblePerson  EmployerSize  \
# 0  Michael McGovern (Chief Operating Officer)    500 to 999
# 1             Philip Galt (Managing Director)    250 to 499
# 2                        Michael Graham (CEO)  1000 to 4999
# 3          Chloe Lines (Financial Controller)    250 to 499
# 4                      Kate Perceval (Bursar)    250 to 499
#
#                             CurrentName  SubmittedAfterTheDeadline  \
# 0       "Bryanston School",Incorporated                      False
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED                      False
# 2                           118 LIMITED                      False
# 3                     123 EMPLOYEES LTD                      False
# 4                            1509 GROUP                      False
#
#                DueDate        DateSubmitted
# 0  05/04/2019 00:00:00  03/04/2019 13:43:34
# 1  05/04/2019 00:00:00  01/04/2019 12:37:21
# 2  05/04/2019 00:00:00  06/03/2019 13:26:24
# 3  05/04/2019 00:00:00  03/04/2019 15:43:17
# 4  05/04/2019 00:00:00  18/03/2019 14:03:16
#
# [5 rows x 25 columns]

# %% [markdown]
# > Change the code above to look at the first ten rows
# >
# > What about the last ten rows?
# >
# > Everything *but* the last ten rows?

# %% [markdown]
# ## Check the column headings

# %%
data.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName',
#        'SubmittedAfterTheDeadline', 'DueDate', 'DateSubmitted'],
#       dtype='object')

# %% [markdown]
# ## Find the largest mean pay gap

# %%
data.DiffMeanHourlyPercent.max()
# Out:
# 100.0

# %% [markdown]
# > How would you interpret this pay gap?
# >
# > What is the lowest mean pay gap?
# >
# > What are the highest and lowest *median* pay gaps?

# %% [markdown]
# ## Sort by pay gap

# %%
data.sort_values(by='DiffMedianHourlyPercent', axis=0, ascending=False).head()
# Out:
#                                  EmployerName  \
# 8952                T. CLASS SECURITY LIMITED
# 629               ASH & LACY FINISHES LIMITED
# 10198                 VIDA HEALTHCARE LIMITED
# 8822             SUFFOLK GP FEDERATION C.I.C.
# 6427   NEW MILLENNIA PAYROLL SERVICES LIMITED
#
#                                                  Address CompanyNumber  \
# 8952   6 Skylines Village,\r\nLimeharbour,\r\nLondon,...      03622392
# 629    Ash & Lacy House, Bromford Lane,\r\nWest Bromw...      10805186
# 10198  The Power House, 156 Hookstone Drive,\r\nHarro...      09106261
# 8822   Riverside Clinic, 2 Landseer Road,\r\nIpswich,...      06183049
# 6427     1121 Ashton Old Road,\r\nManchester,\r\nM11 1AA      04254121
#
#       SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 8952     80100                  100.0                    100.0
# 629      32990                  100.0                    100.0
# 10198    41100                   70.4                     79.3
# 8822     86210                   59.5                     74.8
# 6427     78200                    6.6                     74.3
#
#        DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 8952                  100.0                   100.0             100.0
# 629                     NaN                     NaN               0.0
# 10198                   0.0                     0.0               0.0
# 8822                    NaN                     NaN               0.0
# 6427                   36.6                    60.0               2.0
#
#        FemaleBonusPercent  ...  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 8952                100.0  ...                       50.0             50.0
# 629                   0.0  ...                        0.0            100.0
# 10198                 0.0  ...                       67.0             50.0
# 8822                  0.0  ...                       87.5             37.5
# 6427                  2.2  ...                       10.6             92.1
#
#        FemaleTopQuartile                               CompanyLinkToGPGInfo  \
# 8952                50.0                             https://t-class.co.uk/
# 629                  0.0  http://www.ashandlacy.com/construction/about-u...
# 10198               50.0                                                NaN
# 8822                62.5                         https://suffolkfed.org.uk/
# 6427                 7.9                                                NaN
#
#                             ResponsiblePerson  EmployerSize  \
# 8952            Demi Larner (Vetting Officer)    250 to 499
# 629           Jonathan Evans (CEO & Chairman)    250 to 499
# 10198       James Rycroft (Managing Director)    250 to 499
# 8822   Katrina Pollard (Financial Controller)    250 to 499
# 6427                Nicholas Hynes (Director)  1000 to 4999
#
#                                   CurrentName  SubmittedAfterTheDeadline  \
# 8952                T. CLASS SECURITY LIMITED                       True
# 629               ASH & LACY FINISHES LIMITED                      False
# 10198                 VIDA HEALTHCARE LIMITED                      False
# 8822             SUFFOLK GP FEDERATION C.I.C.                      False
# 6427   NEW MILLENNIA PAYROLL SERVICES LIMITED                      False
#
#                    DueDate        DateSubmitted
# 8952   05/04/2019 00:00:00  08/05/2019 11:08:24
# 629    05/04/2019 00:00:00  03/04/2019 08:56:20
# 10198  05/04/2019 00:00:00  18/03/2019 11:10:56
# 8822   05/04/2019 00:00:00  26/03/2019 13:36:06
# 6427   05/04/2019 00:00:00  27/03/2019 11:45:19
#
# [5 rows x 25 columns]

# %% [markdown]
# > Edit the code above to sort by *median* pay gap
# >
# >
# > Edit the code to put the results in *ascending* order

# %% [markdown]
# ## Filtering the data
#
# Let's see how many companies reported a mean pay gap of more than 50%

# %%
data.loc[data.DiffMeanHourlyPercent > 50]
# Out:
#                                             EmployerName  \
# 87                            ABERDEEN FOOTBALL CLUB PLC
# 227                              AFC BOURNEMOUTH LIMITED
# 312    ALBION FOOTBALL CLUB(BURTON-ON-TRENT)LIMITED(THE)
# 429                          AMEC FOSTER WHEELER LIMITED
# 447                                     AMPLIFON LIMITED
# ...                                                  ...
# 10453              WEST HAM UNITED FOOTBALL CLUB LIMITED
# 10642  WOLVERHAMPTON WANDERERS FOOTBALL CLUB (1986) L...
# 10689                               WRFC TRADING LIMITED
# 10743                                       YELL LIMITED
# 10785                             YOURS CLOTHING LIMITED
#
#                                                  Address CompanyNumber  \
# 87     Pittodrie Stadium, Pittodrie Street,\r\nAberde...      SC005364
# 227    Vitality Stadium Dean Court,\r\nKings Park,\r\...      06632170
# 312    Pirelli Stadium, Princess Way,\r\nBurton On Tr...      00488096
# 429    Booths Park,\r\nChelford Road,\r\nKnutsford,\r...      01675285
# 447    Gateway House,\r\nStyal Road,\r\nManchester,\r...      01315581
# ...                                                  ...           ...
# 10453  London Stadium,\r\nQueen Elizabeth Olympic Par...      00066516
# 10642  Molineux Stadium,\r\nWaterloo Road,\r\nWolverh...      01989823
# 10689  Sixways Stadium Warriors Way,\r\nHindlip,\r\nW...      03160145
# 10743  3 Forbury Place,\r\nForbury Road,\r\nReading,\...      04205228
# 10785  Newcombe House,\r\nBakewell Road, Orton Southg...      02886196
#
#               SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 87     93110,\r\n93120                   55.6                     26.6
# 227              93120                   85.7                     22.1
# 312              93110                   52.3                      7.1
# 429              70100                   51.0                     52.6
# 447              86900                   55.0                     68.0
# ...                ...                    ...                      ...
# 10453            93120                   85.1                     20.6
# 10642            93120                   63.3                     15.9
# 10689            93110                   51.1                     14.0
# 10743  58120,\r\n58190                   54.6                     23.1
# 10785            47710                   65.0                     54.0
#
#        DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 87                     75.0                    65.3              15.4
# 227                    99.7                    99.4              16.0
# 312                   100.0                   100.0              11.0
# 429                    76.5                    72.7              98.0
# 447                    34.0                    50.0              76.0
# ...                     ...                     ...               ...
# 10453                  30.4                  -100.0              22.3
# 10642                  96.7                    65.0              21.0
# 10689                  51.6                     9.1              11.3
# 10743                  95.6                    14.1              92.7
# 10785                  57.0                    61.0              76.0
#
#        FemaleBonusPercent  ...  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 87                    1.6  ...                       27.3             92.4
# 227                   2.1  ...                       21.4             78.2
# 312                   0.0  ...                       36.5             87.3
# 429                  94.3  ...                       57.6             56.2
# 447                  29.0  ...                       62.0             59.0
# ...                   ...  ...                        ...              ...
# 10453                 4.7  ...                       25.4             88.3
# 10642                12.0  ...                       20.4             90.0
# 10689                 0.5  ...                       30.0             85.0
# 10743                94.4  ...                       23.0             69.0
# 10785                26.0  ...                       99.0             10.0
#
#        FemaleTopQuartile                               CompanyLinkToGPGInfo  \
# 87                   7.6  https://d2cx26qpfwuhvu.cloudfront.net/aberdeen...
# 227                 21.8  https://www.afcb.co.uk/news/club-news/gender-p...
# 312                 12.7                                                NaN
# 429                 43.8  https://www.woodplc.com/policies-and-notices/g...
# 447                 41.0                                                NaN
# ...                  ...                                                ...
# 10453               11.7  https://www.whufc.com/news/articles/2019/march...
# 10642               10.0  https://prod-wolves-cms.azurewebsites.net/medi...
# 10689               15.0  https://warriors.co.uk/fanzone/club-informatio...
# 10743               31.0  https://irp-cdn.multiscreensite.com/c0e9065d/f...
# 10785               90.0     https://www.yoursclothing.co.uk/gender-pay-gap
#
#                                        ResponsiblePerson   EmployerSize  \
# 87                      Roy Johnston (Company Secretary)     250 to 499
# 227                     David Holiday (Finance Director)     500 to 999
# 312                 Fleur Robinson (Commercial Director)     250 to 499
# 429    Sue MacDonald (Executive President - People & ...  Less than 250
# 447                     Giuseppe Manzo (General Manager)     250 to 499
# ...                                                  ...            ...
# 10453                          Michele Gull (Head of HR)     250 to 499
# 10642                            Zoe Brough (Head of HR)     500 to 999
# 10689                  Peter Kelly (Operations Director)     500 to 999
# 10743                          David Sharman (Group CEO)     250 to 499
# 10785                    Anna Heather (Finance Director)   1000 to 4999
#
#                                              CurrentName  \
# 87                            ABERDEEN FOOTBALL CLUB PLC
# 227                              AFC BOURNEMOUTH LIMITED
# 312    ALBION FOOTBALL CLUB(BURTON-ON-TRENT)LIMITED(THE)
# 429                          AMEC FOSTER WHEELER LIMITED
# 447                                     AMPLIFON LIMITED
# ...                                                  ...
# 10453              WEST HAM UNITED FOOTBALL CLUB LIMITED
# 10642  WOLVERHAMPTON WANDERERS FOOTBALL CLUB (1986) L...
# 10689                               WRFC TRADING LIMITED
# 10743                                       YELL LIMITED
# 10785                             YOURS CLOTHING LIMITED
#
#        SubmittedAfterTheDeadline              DueDate        DateSubmitted
# 87                         False  05/04/2019 00:00:00  28/03/2019 10:04:46
# 227                        False  05/04/2019 00:00:00  28/03/2019 12:17:49
# 312                        False  05/04/2019 00:00:00  03/04/2019 09:01:57
# 429                        False  05/04/2019 00:00:00  25/02/2019 09:43:16
# 447                        False  05/04/2019 00:00:00  03/04/2019 08:59:15
# ...                          ...                  ...                  ...
# 10453                      False  05/04/2019 00:00:00  28/03/2019 10:07:33
# 10642                      False  05/04/2019 00:00:00  04/04/2019 12:52:09
# 10689                       True  05/04/2019 00:00:00  02/05/2019 10:29:14
# 10743                      False  05/04/2019 00:00:00  01/04/2019 17:48:50
# 10785                      False  05/04/2019 00:00:00  26/03/2019 13:38:47
#
# [144 rows x 25 columns]

# %% [markdown]
# > What do you notice?
# >
# > How many companies reported a mean pay gap in favour of women? What *proportion* of companies is this?
# >
# > How many companies reported a *median* pay gap in favour of women?
# >
# > What proportion of companies reported a higher mean pay gap than median pay gap? Why is this?

# %% [markdown]
# ## Searching by `SIC` code
#
# Let's look at some companies in the tech sector
#
# [SIC code reference](http://www.siccodesupport.co.uk/) says that SIC codes that start with 62 are for companies that do "Computer programming, consultancy, and related activities"

# %%
data.loc[data.SicCodes.str.startswith("62", na=False)]
# Out:
#                                            EmployerName  \
# 115                                       Access UK Ltd
# 141                        ACI WORLDWIDE (EMEA) LIMITED
# 167                                     ACTURIS LIMITED
# 204                                ADVANCED 365 LIMITED
# 205    ADVANCED BUSINESS SOFTWARE AND SOLUTIONS LIMITED
# ...                                                 ...
# 10602                     WIN TECHNOLOGIES (UK) LIMITED
# 10675                  WORLDLINE IT SERVICES UK LIMITED
# 10683                                   WOWCHER LIMITED
# 10723      XCHANGING GLOBAL INSURANCE SOLUTIONS LIMITED
# 10794                 ZEBRA TECHNOLOGIES EUROPE LIMITED
#
#                                                  Address CompanyNumber  \
# 115    The Old School,\r\nSchool Lane,\r\nStratford S...      02343760
# 141    55-57 Clarendon Road,\r\nWatford,\r\nHertfords...      02310474
# 167    Courtyard Suite, 100 Hatton Garden,\r\nLondon,...      03998084
# 204    Ditton Park,\r\nRiding Court Road,\r\nDatchet,...      02124540
# 205    Ditton Park,\r\nRiding Court Road,\r\nDatchet,...      03214465
# ...                                                  ...           ...
# 10602  55 Baker Street,\r\nLondon,\r\nEngland,\r\nW1U...      05771461
# 10675  Second Floor, Mid City Place,\r\n71 High Holbo...      08514184
# 10683  Wowcher Towers 12-27 Swan Yard, Islington,\r\n...      04264984
# 10723  Royal Pavilion,\r\nWellesley Road,\r\nAldersho...      00508212
# 10794  Dukes Meadow,\r\nMillboard Road,\r\nBourne End...      02881068
#
#                         SicCodes  DiffMeanHourlyPercent  \
# 115                        62090                   19.9
# 141              62020,\r\n70100                    8.9
# 167                        62090                   18.8
# 204                        62090                    8.3
# 205                        62020                   24.5
# ...                          ...                    ...
# 10602                      62090                   43.0
# 10675  62020,\r\n62090,\r\n63990                   20.8
# 10683                      62090                   30.4
# 10723                      62020                   27.0
# 10794                      62012                   11.4
#
#        DiffMedianHourlyPercent  DiffMeanBonusPercent  DiffMedianBonusPercent  \
# 115                       24.3                  41.2                    10.5
# 141                       20.7                  26.5                    75.7
# 167                       16.3                  55.6                    17.4
# 204                       19.4                  30.0                    19.0
# 205                       33.0                  69.0                     3.0
# ...                        ...                   ...                     ...
# 10602                     25.0                  33.0                    22.0
# 10675                     19.2                   5.6                    29.0
# 10683                     34.4                  64.3                    80.1
# 10723                     23.0                  16.0                    15.0
# 10794                     26.6                  32.5                    42.8
#
#        MaleBonusPercent  FemaleBonusPercent  ...  FemaleUpperMiddleQuartile  \
# 115                56.1                48.6  ...                       27.0
# 141                81.6                78.8  ...                       22.0
# 167                80.9                78.0  ...                       24.4
# 204                99.0                97.0  ...                        8.0
# 205                84.0                91.0  ...                       28.0
# ...                 ...                 ...  ...                        ...
# 10602              76.0                75.0  ...                       28.0
# 10675              68.0                55.0  ...                       22.0
# 10683              56.3                56.8  ...                       39.0
# 10723              10.0                 4.0  ...                       10.0
# 10794              92.4                92.2  ...                       28.8
#
#        MaleTopQuartile  FemaleTopQuartile  \
# 115               81.0               19.0
# 141               73.0               27.0
# 167               85.9               14.1
# 204               87.0               13.0
# 205               86.0               14.0
# ...                ...                ...
# 10602             83.0               17.0
# 10675             80.0               20.0
# 10683             70.0               30.0
# 10723             89.0               11.0
# 10794             80.9               19.1
#
#                                     CompanyLinkToGPGInfo  \
# 115    https://www.theaccessgroup.com/company/our-peo...
# 141    https://www.aciworldwide.com/-/media/files/col...
# 167    https://www.acturis.com/wp-content/uploads/201...
# 204    https://www.oneadvanced.com/siteassets/resourc...
# 205    https://www.oneadvanced.com/siteassets/resourc...
# ...                                                  ...
# 10602                                                NaN
# 10675  https://uk.worldline.com/content/dam/worldline...
# 10683        https://www.wowcher.co.uk/page/aboutus.html
# 10723  https://www.dxc.technology/uki/ds/11507/146310...
# 10794  https://www.zebra.com/content/dam/zebra_new_ia...
#
#                                  ResponsiblePerson  EmployerSize  \
# 115                             Claire Scott (CPO)  1000 to 4999
# 141                       David King (VP Services)    250 to 499
# 167                      David McDonald (Director)    250 to 499
# 204                    Alex Arundale (HR Director)    250 to 499
# 205                    Alex Arundale (HR Director)    500 to 999
# ...                                            ...           ...
# 10602           Brian Susskind (Managing Director)    250 to 499
# 10675           Lisa Coleman (CEO Worldline, UK&I)    500 to 999
# 10683  Karen Kemble-Diaz (Chief Operating Officer)    250 to 499
# 10723      Holly Hamilton (Director Total Rewards)    250 to 499
# 10794     Shelley Eades (Director Human Resources)    500 to 999
#
#                                             CurrentName  \
# 115                                       Access UK Ltd
# 141                        ACI WORLDWIDE (EMEA) LIMITED
# 167                                     ACTURIS LIMITED
# 204                                ADVANCED 365 LIMITED
# 205    ADVANCED BUSINESS SOFTWARE AND SOLUTIONS LIMITED
# ...                                                 ...
# 10602                     WIN TECHNOLOGIES (UK) LIMITED
# 10675                  WORLDLINE IT SERVICES UK LIMITED
# 10683                                   WOWCHER LIMITED
# 10723      XCHANGING GLOBAL INSURANCE SOLUTIONS LIMITED
# 10794                 ZEBRA TECHNOLOGIES EUROPE LIMITED
#
#        SubmittedAfterTheDeadline              DueDate        DateSubmitted
# 115                        False  05/04/2019 00:00:00  20/03/2019 16:54:52
# 141                        False  05/04/2019 00:00:00  02/04/2019 16:30:35
# 167                        False  05/04/2019 00:00:00  27/03/2019 16:20:50
# 204                        False  05/04/2019 00:00:00  03/04/2019 12:09:40
# 205                        False  05/04/2019 00:00:00  03/04/2019 12:02:28
# ...                          ...                  ...                  ...
# 10602                      False  05/04/2019 00:00:00  01/04/2019 14:03:36
# 10675                      False  05/04/2019 00:00:00  29/03/2019 09:04:41
# 10683                      False  05/04/2019 00:00:00  27/03/2019 10:14:59
# 10723                      False  05/04/2019 00:00:00  13/03/2019 14:21:06
# 10794                      False  05/04/2019 00:00:00  29/03/2019 06:49:07
#
# [234 rows x 25 columns]

# %% [markdown]
# > How many companies have SIC codes that start with 62?
# >
# > How many of these companies have a pay gap in favour of women? What *proportion* is this?

# %% [markdown]
# ## Quartiles
#
# Let's look at one particular company and the composition of their pay *quartiles*

# %%
# Select columns by number using `iloc`
# The quartile data is in columns 10 to 17
# Transpose for ease of reading
data.loc[data.EmployerName.str.startswith("VOD", na=False)].iloc[:,[0,4,5,10,11,12,13,14,15,16,17]].transpose()
# Out:
#                                                         10240  \
# EmployerName               VODAFONE GLOBAL ENTERPRISE LIMITED
# DiffMeanHourlyPercent                                    22.3
# DiffMedianHourlyPercent                                  21.7
# MaleLowerQuartile                                        44.8
# FemaleLowerQuartile                                      55.2
# MaleLowerMiddleQuartile                                  69.8
# FemaleLowerMiddleQuartile                                30.2
# MaleUpperMiddleQuartile                                  76.6
# FemaleUpperMiddleQuartile                                23.4
# MaleTopQuartile                                          73.3
# FemaleTopQuartile                                        26.7
#
#                                                      10241             10242
# EmployerName               VODAFONE GROUP SERVICES LIMITED  VODAFONE LIMITED
# DiffMeanHourlyPercent                                 16.8              15.3
# DiffMedianHourlyPercent                                6.4              19.3
# MaleLowerQuartile                                       58              57.7
# FemaleLowerQuartile                                     42              42.3
# MaleLowerMiddleQuartile                               63.1              60.2
# FemaleLowerMiddleQuartile                             36.9              39.8
# MaleUpperMiddleQuartile                               68.9              69.4
# FemaleUpperMiddleQuartile                             31.1              30.6
# MaleTopQuartile                                       69.4                76
# FemaleTopQuartile                                     30.6                24

# %% [markdown]
# > What do you think is meant by these figures?
# >
# > Use this information to suggest a reason for the pay gap at this company
